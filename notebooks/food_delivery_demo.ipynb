# %%
from food_delivery_time.data import load_data
from food_delivery_time.model import train_simple_model

df = load_data("../data/deliverytime.csv")
df.head()

# %%
model, score = train_simple_model(df)
print("MAE score:", score)
